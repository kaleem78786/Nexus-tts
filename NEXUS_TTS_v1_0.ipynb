# %% [markdown]
# [NEXUS TTS V1.0](https://huggingface.co/hexgrad/Kokoro-82M)

# %%
#@title Install NEXUS TTS
# %cd /content/
# !git clone https://github.com/NeuralFalconYT/Kokoro-TTS-Subtitle.git NEXUS-TTS
# %cd /content/NEXUS-TTS
# !pip install -r requirements.txt
# !apt-get -qq -y install espeak-ng > /dev/null 2>&1
from IPython.display import clear_output
clear_output()

# %%
# %cd /content/NEXUS-TTS
# !python beta.py --share
# !python srt_dub.py --share
# !python app.py --share
# Out:
#  66% 23/35 [00:27<00:08,  1.49it/s]
